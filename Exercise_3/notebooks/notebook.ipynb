# %% [markdown]
# # Exercise 3 - Notebook
# **Description:** This is just a notebook for my exercise to show that I understand how to create a reproducible workflow.

# %%
import panda as pd
import Bio as SeqIO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import panda as pd
#       2 import Bio as SeqIO
#
# ModuleNotFoundError: No module named 'panda'

# %%
# Read sequence records one by one
for record in SeqIO.parse("data/Fet3_6Genomes.fasta", "fasta"):
    print(f"ID: {record.id}")
    print(f"Description: {record.description}")
    print(f"Sequence: {record.seq}")
    print(f"Length: {len(record.seq)}\n")
# Out:
# Running cells with 'Exercise_3 (3.13.13) (Python 3.13.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/labergnilsson/Documents/BERN_02/Exercise_3/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
